# %% [markdown]
# #### Download tabula sapiens v2
# via CLI

# %%
wget https://datasets.cellxgene.cziscience.com/1c88f927-bcbb-4bb1-9881-281842945a2d.h5ad

# %% [markdown]
# #### Imports

# %%
import pandas as pd
import scanpy as sc
from pathlib import Path
from typing import Union

# %%
# Load anndata
adata = sc.read_h5ad("1c88f927-bcbb-4bb1-9881-281842945a2d.h5ad")
